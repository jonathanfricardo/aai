# %%
from IPython.display import Image, display

display(Image("Screenshot 2024-02-27 at 09.49.25.png"))
display(Image("Screenshot 2024-02-27 at 09.56.10.png"))
display(Image("Screenshot 2024-02-27 at 09.58.47.png"))
display(Image("Screenshot 2024-02-27 at 10.24.03.png"))
display(Image("Screenshot 2024-02-27 at 10.31.17.png"))
display(Image("Screenshot 2024-02-27 at 10.31.40.png"))
display(Image("Screenshot 2024-02-27 at 10.40.25.png"))
display(Image("Screenshot 2024-02-27 at 10.43.11.png"))
display(Image("Screenshot 2024-02-27 at 10.49.54.png"))
display(Image("Screenshot 2024-02-27 at 10.56.10.png"))
